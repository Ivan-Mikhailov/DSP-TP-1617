# %%
# Digital Signal Processing

### MsCV - ViBOT - MAIA

# %% [markdown]
# The reasons to convert signals into frequency domain is to get the idea of different frequency components it is composed of. This might help to detect the required signals and classify them, for examples, speak or speech recognition from a sound wave, noise removal from the image, or finding recurring patterns within images.

# %%
# %matplotlib inline
# %pprint off

# To make some nice plot
import matplotlib.pyplot as plt
# To play with arrays
import numpy as np
from skimage import io
from skimage import img_as_float
from matplotlib import cm
from scipy.stats import norm
from scipy import signal
from numpy import random
from skimage import color
# Out:
# Pretty printing has been turned OFF

# %% [markdown]
# # Discrete Fourier Transform
# The Discrete Fourier Transform (DFT) converts discrete data from a time domain into frequency domain. The DFT analyzes the finite segment in one period of an infinitely extended periodic signal, which is defined as:
# $$ X[n] = \sum^{N-1}_{k = 0} x[k] e^{-j(2\pi/N)kn}$$
#
#
# Note: The Fast Fourier Transform (FFT) is simply an algorithm to compute the DFT in a faster way!
#
# ## Exercise 1 -  ** DFT**
# **1.1** The DFT of a $5$ Hz sin wave sampled with the sampling of $f_s = 50$ Hz over 1000 (N = 1000) samples is computed as follows:

# %%
def output(t, x_n,fr, x_f, title1, title2, title3, title4, title5):
    plt.figure
    plt.subplot(211)
    plt.plot(t, x_n)
    plt.title(title1)
    plt.xlabel('Time(sec)')
    plt.ylabel('Amplitude')
    plt.show()

    plt.subplot(312)
    plt.plot(fr, x_f)
    plt.title(title2)
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('|X(f)|')
    plt.show()

    plt.subplot(313)
    plt.plot(fr, np.abs(x_f))
    plt.title(title3)
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('|X(f)|')
    plt.show()

    plt.figure
    plt.subplot(211)
    plt.plot(fr, np.real(x_f))
    plt.title(title4)
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('Re(X(f))')
    plt.show()

    plt.subplot(212)
    plt.plot(fr, np.imag(x_f))
    plt.title(title5)
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('Im(X(f))')
    plt.show()


# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for one second
t = np.arange(0, 1., 1./fs)
# sin wave 
x_n = np.sin(2*np.pi*f*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

output(t, x_n,fr, x_f,'Sin wave Signal','DFT','Magnitude','Real','Imaginary')
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# **1.2** Compute the DFT of a cosine wave, how that differs from that of a sine wave ?

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for one second
t = np.arange(0, 1., 1./fs)
# cos wave 
x_n = np.cos(2*np.pi*f*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

output(t, x_n,fr, x_f,'Cos wave Signal','DFT','Magnitude','Real','Imaginary')
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# **1.3** Use square wave using the same frequncy and sampling frequency.
#
# Note use `signal.square` to create your signal.

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# Number of samples 
N = 1000
# time vector for one second
t = np.arange(0, 1., 1./fs)
# cos wave 
x_n = signal.square(2*np.pi*f*t)

# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

output(t, x_n,fr, x_f,'Square signal','DFT','Magnitude','Real','Imaginary')
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# **1.4** Use white Gaussian noise N = 10000.
#
# (Note use `np.random.normal` to create your noise)

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# Number of samples 
N = 10000
# time vector for one second
t = np.arange(0, 1., 1./fs)
# cos wave 
x_n = random.normal(size = t.shape[0])

# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

#output(t, x_n,fr, x_f,'Gaussian noise signal','DFT','Magnitude','Real','Imaginary')
plt.figure
plt.plot(x_n)
plt.title('Gaussian Noise')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.figure
plt.plot(x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ## Exercise 2 -  Sampling
#
# Generate and display the following signals of 1 sec duration.
# $$x[n] = 3 cos(2\pi\frac{f_{1}}{f_{s}}n) + 4 sin(2\pi\frac{f_{2}}{f_{s}}n)$$
# for $f_{1} = 5$ Hz and $f_{2} = 20$ Hz, sampled with the sampling frequencies of $f_{s} = [10, 20, 25, 40, 50, 100, 150]$

# %% [markdown]
# **2.1** Plot $x[n]$ for different sampling frequencies in time domain.

# %%
def sign(fs):
    # Signal frequency and sampling frequency
    f1 = 5.
    f2 = 20.
    # time vector for one second
    n = np.arange(0, 1., 1./fs)
    signal = 3*np.cos(2*np.pi*(f1)*n)+4*np.sin((2*np.pi)*(f2)*n)
    return n,signal


plt.figure
#plt.subplot(211)
n, s = sign(10)
plt.plot(n,s)
plt.title('fs = 10')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.figure
n,s = sign(20)
#plt.subplot(211)
plt.plot(n,s)
plt.title('fs = 20')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.figure
n,s = sign(25)
#plt.subplot(211)
plt.plot(n,s)
plt.title('fs = 25')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.figure
n,s = sign(40)
#plt.subplot(211)
plt.plot(n,s)
plt.title('fs = 40')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.figure
n,s = sign(50)
#plt.subplot(211)
plt.plot(n,s)
plt.title('fs = 50')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.figure
n,s = sign(100)
#plt.subplot(211)
plt.plot(n,s)
plt.title('fs = 100')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.figure
n,s = sign(150)
#plt.subplot(211)
plt.plot(n,s)
plt.title('fs = 150')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# **2.2.** Discuss the aliasing effects in the time domain:

# %% [markdown]
# **2.3** Compute the FFT of the above signals and display their centered frequency components.
# Discuss your observations.

# %%
x = np.array([10, 20, 25, 40, 50, 100, 150])
for i in x:
    n, s = sign(i)
    # Number of samples 
    N = 1000
    # frequency vector
    fr = (np.arange(-N/2,N/2,1)) * i/N
    # DFT 
    # Using fftshift to have the center frequency 
    x_f = np.fft.fftshift(np.fft.fft(s, N))
    #x_f = x_f[0:N/2]
    
    plt.figure
    plt.subplot(211)
    plt.plot(n, s)
    plt.title('Signal, fs=%d' %i)
    plt.xlabel('Time(sec)')
    plt.ylabel('Amplitude')
    plt.show()

    plt.subplot(312)
    plt.plot(fr, x_f)
    plt.title('DFT, fs=%d'%i)
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('|X(f)|')
    plt.show()

    plt.subplot(313)
    plt.plot(fr, np.abs(x_f))
    plt.title('Magnitude, fs=%d'%i)
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('|X(f)|')
    plt.show()

    plt.figure
    plt.subplot(211)
    plt.plot(fr, np.real(x_f))
    plt.title('Real, fs=%d'%i)
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('Re(X(f))')
    plt.show()

    plt.subplot(212)
    plt.plot(fr, np.imag(x_f))
    plt.title('Imaginary, fs=%d'%i)
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('Im(X(f))')
    plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ## Exercise 3 - 1D  DFT for image classification
#
# 1D DFT can be applied to analyze the frequency components along the one dimensional profile of an image. Here we want to use these information to classify the images into two different classes (**barcode** and **non-barcode** classes)
# To do so we first
# * Load the images from 1D-DFT folder
#     * **3.1** you have to normalize and resize the images to the smallest size
#     * **3.2** Take 1D profile as shown in the example and compute its DFT.
# ![](profile1.png)
#
#     * **3.3** Separate the images to two different groups of **barcode** and **non-barcode** based on their frequency spectrum of their profile
# * Some information regarding the images:
#     * There are 54 images while Images [1, 2, 6, 44:54] are barcode images and the others are similar patterns.
#
# **3.4** Discuss your results

# %%
Path = '../images/1D-DFT/'
import os, os.path
from skimage import color
from scipy import misc

filenames = sorted([f for f in os.listdir(Path)])

Img = img_as_float(color.rgb2gray(io.imread(os.path.join(Path,filenames[0]))))
min_x_shape = Img.shape[0]
min_y_shape = Img.shape[1]
#print(min_x_shape,min_y_shape)

for f in filenames:   
    Img = img_as_float(color.rgb2gray(io.imread(os.path.join(Path,f))))
    Img *= (255.0/Img.max())
    
    print("Img",f,Img.shape)

    if f == filenames[-1]:
        for f2 in filenames:
            Img = img_as_float(color.rgb2gray(io.imread(os.path.join(Path,f2))))
            Img = misc.imresize(Img, [min_x_shape,min_y_shape])
            print("IMAGE SIZE CHANGED",f2,'NEW SIZE:',Img.shape)
            Img = Img[int(Img.shape[0]/2),:]
            print(Img.shape)
            N = Img.shape[0]
            fr = (np.arange(-N/2,N/2,1))
            x_f -= x_f.min()
            x_f /= x_f.max()
            x_f = np.abs(np.fft.fftshift(np.fft.fft(Img, N)))
            plt.plot(fr, x_f)
    elif min_x_shape > Img.shape[0] and min_y_shape > Img.shape[0]:
                min_x_shape = Img.shape[0]
                min_y_shape = Img.shape[1]
    elif min_x_shape > Img.shape[0]:
                min_x_shape = Img.shape[0]
    elif min_y_shape > Img.shape[1]:
                min_x_shape = Img.shape[0]
    else: print('This image is bigger\n')
#print(min_x_shape,min_y_shape)
# Out:
# Img tifImage_001.tif (145, 264)
# This image is bigger
#
# Img tifImage_002.tif (66, 131)
# Img tifImage_003.tif (100, 212)
# This image is bigger
#
# Img tifImage_004.tif (139, 207)
# This image is bigger
#
# Img tifImage_005.tif (116, 227)
# This image is bigger
#
# Img tifImage_006.tif (125, 310)
# This image is bigger
#
# Img tifImage_007.tif (99, 268)
# This image is bigger
#
# Img tifImage_008.tif (165, 354)
# This image is bigger
#
# Img tifImage_009.tif (93, 175)
# This image is bigger
#
# Img tifImage_010.tif (116, 266)
# This image is bigger
#
# Img tifImage_011.tif (120, 197)
# This image is bigger
#
# Img tifImage_012.tif (158, 233)
# This image is bigger
#
# Img tifImage_013.tif (134, 277)
# This image is bigger
#
# Img tifImage_014.tif (136, 284)
# This image is bigger
#
# Img tifImage_015.tif (147, 257)
# This image is bigger
#
# Img tifImage_016.tif (151, 381)
# This image is bigger
#
# Img tifImage_017.tif (191, 346)
# This image is bigger
#
# Img tifImage_018.tif (140, 243)
# This image is bigger
#
# Img tifImage_019.tif (107, 173)
# This image is bigger
#
# Img tifImage_020.tif (132, 185)
# This image is bigger
#
# Img tifImage_021.tif (88, 170)
# This image is bigger
#
# Img tifImage_022.tif (138, 182)
# This image is bigger
#
# Img tifImage_023.tif (138, 217)
# This image is bigger
#
# Img tifImage_024.tif (172, 216)
# This image is bigger
#
# Img tifImage_025.tif (152, 268)
# This image is bigger
#
# Img tifImage_026.tif (193, 272)
# This image is bigger
#
# Img tifImage_027.tif (175, 263)
# This image is bigger
#
# Img tifImage_028.tif (186, 255)
# This image is bigger
#
# Img tifImage_029.tif (161, 231)
# This image is bigger
#
# Img tifImage_030.tif (163, 194)
# This image is bigger
#
# Img tifImage_031.tif (180, 227)
# This image is bigger
#
# Img tifImage_032.tif (169, 191)
# This image is bigger
#
# Img tifImage_033.tif (180, 225)
# This image is bigger
#
# Img tifImage_034.tif (142, 268)
# This image is bigger
#
# Img tifImage_035.tif (73, 135)
# This image is bigger
#
# Img tifImage_036.tif (150, 200)
# This image is bigger
#
# Img tifImage_037.tif (150, 200)
# This image is bigger
#
# Img tifImage_038.tif (150, 200)
# This image is bigger
#
# Img tifImage_039.tif (150, 200)
# This image is bigger
#
# Img tifImage_040.tif (150, 200)
# This image is bigger
#
# Img tifImage_041.tif (150, 200)
# This image is bigger
#
# Img tifImage_042.tif (150, 200)
# This image is bigger
#
# Img tifImage_043.tif (150, 200)
# This image is bigger
#
# Img tifImage_044.tif (182, 231)
# This image is bigger
#
# Img tifImage_045.tif (381, 509)
# This image is bigger
#
# Img tifImage_046.tif (149, 225)
# This image is bigger
#
# Img tifImage_047.tif (97, 138)
# This image is bigger
#
# Img tifImage_048.tif (166, 258)
# This image is bigger
#
# Img tifImage_049.tif (321, 461)
# This image is bigger
#
# Img tifImage_050.tif (313, 404)
# This image is bigger
#
# Img tifImage_051.tif (237, 316)
# This image is bigger
#
# Img tifImage_052.tif (113, 255)
# This image is bigger
#
# Img tifImage_053.tif (176, 203)
# This image is bigger
#
# Img tifImage_054.tif (233, 277)
# IMAGE SIZE CHANGED tifImage_001.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_002.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_003.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_004.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_005.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_006.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_007.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_008.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_009.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_010.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_011.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_012.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_013.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_014.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_015.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_016.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_017.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_018.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_019.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_020.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_021.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_022.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_023.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_024.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_025.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_026.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_027.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_028.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_029.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_030.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_031.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_032.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_033.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_034.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_035.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_036.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_037.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_038.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_039.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_040.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_041.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_042.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_043.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_044.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_045.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_046.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_047.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_048.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_049.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_050.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_051.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_052.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_053.tif NEW SIZE: (66, 131)
# (131,)
# IMAGE SIZE CHANGED tifImage_054.tif NEW SIZE: (66, 131)
# (131,)
